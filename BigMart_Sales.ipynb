# %% [markdown]
# **Read CSV file**

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Satyam-Dataanalyst/BigMart-Sales-Analysis-using-Python/refs/heads/main/bigmart.csv'
data = pd.read_csv(url)

# %% [markdown]
# **Review Dataset**

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
pivot = pd.pivot_table(data, index=['Item_Type'], values="Item_Weight", aggfunc= 'mean')
pivot = pivot.rename(columns = {'Item_Weight':'Mean_Weight'})
pivot
# Out:
#                        Mean_Weight
# Item_Type
# Baking Goods             12.277108
# Breads                   11.346936
# Breakfast                12.768202
# Canned                   12.305705
# Dairy                    13.426069
# Frozen Foods             12.867061
# Fruits and Vegetables    13.224769
# Hard Drinks              11.400328
# Health and Hygiene       13.142314
# Household                13.384736
# Meat                     12.817344
# Others                   13.853285
# Seafood                  12.552843
# Snack Foods              12.987880
# Soft Drinks              11.847460
# Starchy Foods            13.690731

# %% [markdown]
# **Alternate Way of Summarizing Table**

# %%
weight_by_item = data.groupby('Item_Type')
weight_by_item.Item_Weight.mean()
# Out:
# Item_Type
# Baking Goods             12.277108
# Breads                   11.346936
# Breakfast                12.768202
# Canned                   12.305705
# Dairy                    13.426069
# Frozen Foods             12.867061
# Fruits and Vegetables    13.224769
# Hard Drinks              11.400328
# Health and Hygiene       13.142314
# Household                13.384736
# Meat                     12.817344
# Others                   13.853285
# Seafood                  12.552843
# Snack Foods              12.987880
# Soft Drinks              11.847460
# Starchy Foods            13.690731
# Name: Item_Weight, dtype: float64

# %%
data.groupby('Item_Type').Item_Weight.mean()
# Out:
# Item_Type
# Baking Goods             12.277108
# Breads                   11.346936
# Breakfast                12.768202
# Canned                   12.305705
# Dairy                    13.426069
# Frozen Foods             12.867061
# Fruits and Vegetables    13.224769
# Hard Drinks              11.400328
# Health and Hygiene       13.142314
# Household                13.384736
# Meat                     12.817344
# Others                   13.853285
# Seafood                  12.552843
# Snack Foods              12.987880
# Soft Drinks              11.847460
# Starchy Foods            13.690731
# Name: Item_Weight, dtype: float64

# %%
pivot_outlet_size = pd.pivot_table(data, index=['Outlet_Size','Outlet_Type'], values='Item_MRP', aggfunc='mean')
pivot_outlet_size
# Out:
#                                  Item_MRP
# Outlet_Size Outlet_Type
# High        Supermarket Type1  141.425982
# Medium      Supermarket Type1  140.297699
#             Supermarket Type2  141.678634
#             Supermarket Type3  139.801791
# Small       Grocery Store      139.787088
#             Supermarket Type1  142.589934

# %%
pd.crosstab(data['Outlet_Size'],data['Item_Type'], margins= False)
# Out:
# Item_Type    Baking Goods  Breads  Breakfast  Canned  Dairy  Frozen Foods  \
# Outlet_Size
# High                   73      25         13      65     80            92
# Medium                203      83         36     217    218           274
# Small                 187      71         30     189    198           249
#
# Item_Type    Fruits and Vegetables  Hard Drinks  Health and Hygiene  \
# Outlet_Size
# High                           142           23                  61
# Medium                         413           75                 170
# Small                          328           50                 136
#
# Item_Type    Household  Meat  Others  Seafood  Snack Foods  Soft Drinks  \
# Outlet_Size
# High               103    41      16        5          125           49
# Medium             289   149      52       21          408          137
# Small              257   119      55       20          335          126
#
# Item_Type    Starchy Foods
# Outlet_Size
# ...

# %%
average_item_visibility = data.groupby(['Item_Identifier'])['Item_Visibility'].mean().reset_index()
average_item_visibility
# Out:
#      Item_Identifier  Item_Visibility
# 0              DRA12         0.031956
# 1              DRA24         0.048062
# 2              DRA59         0.134718
# 3              DRB01         0.082126
# 4              DRB13         0.008002
# ...              ...              ...
# 1554           NCZ30         0.024956
# 1555           NCZ41         0.051623
# 1556           NCZ42         0.009044
# 1557           NCZ53         0.027775
# 1558           NCZ54         0.080426
#
# [1559 rows x 2 columns]

# %%
import numpy as np
average_item_visibility_2 = data.groupby(['Item_Identifier'])['Item_Visibility'].transform('mean')
average_item_visibility_2
# Out:
# 0       0.017387
# 1       0.019219
# 2       0.020145
# 3       0.015274
# 4       0.008082
#           ...
# 8518    0.061705
# 8519    0.046952
# 8520    0.035203
# 8521    0.120686
# 8522    0.051565
# Name: Item_Visibility, Length: 8523, dtype: float64

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# sum of Item_MRP
data.Item_MRP.sum()
# Out:
# np.float64(1201681.4808)

# %%
# average of Item_MRP
data.Item_MRP.mean()
# Out:
# np.float64(140.9927819781767)

# %%
# median of Item_MRP
data.Item_MRP.median()
# Out:
# np.float64(143.0128)

# %%
# mode of Outlet_type.
data.Outlet_Type.mode()
# Out:
# 0    Supermarket Type1
# Name: Outlet_Type, dtype: object

# %%
# outlet_type values_count
data.Outlet_Type.value_counts()
# Out:
# Outlet_Type
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: count, dtype: int64

# %%
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# how to get missing values in each column.
data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Group by items
# if you find output '<pandas.core.groupby.generic.DataFrameGroupBy object at 0x7ec664b4b7a0>' means the result is a dataframe to further access it you have to use "first()" function
data.groupby('Item_Type')

# %%
x = data.groupby('Item_Type').first()
x
# Out:
#                       Item_Identifier  Item_Weight Item_Fat_Content  \
# Item_Type
# Baking Goods                    FDP36       10.395          Regular
# Breads                          FDO23       17.850          Low Fat
# Breakfast                       FDP49        9.000          Regular
# Canned                          FDC14       21.350          Regular
# Dairy                           FDA15        9.300          Low Fat
# Frozen Foods                    FDH17       16.200          Regular
# Fruits and Vegetables           FDX07       19.200          Regular
# Hard Drinks                     DRI11       11.650          Low Fat
# Health and Hygiene              NCB42       11.800          Low Fat
# Household                       NCD19        8.930          Low Fat
# Meat                            FDN15       17.500          Low Fat
# Others                          NCN07       18.500          Low Fat
# Seafood                         FDG33       10.395          Regular
# ...

# %%
# return mean for each row of columns.
import numpy as np

x.mean(axis = 1, numeric_only=True)
# Out:
# Item_Type
# Baking Goods              525.480920
# Breads                    857.499280
# Breakfast                 721.949938
# Canned                    435.180764
# Dairy                    1198.652649
# Frozen Foods              638.357577
# Fruits and Vegetables     586.335000
# Hard Drinks               882.727128
# Health and Hygiene        751.609319
# Household                 608.899320
# Meat                      851.080952
# Others                    482.468403
# Seafood                  1120.307792
# Snack Foods               480.374868
# Soft Drinks               501.326256
# Starchy Foods            1357.935080
# dtype: float64

# %%
x.max(numeric_only=True)
# Out:
# Item_Weight                    21.350000
# Item_Visibility                 0.139561
# Item_MRP                      249.809200
# Outlet_Establishment_Year    2009.000000
# Item_Outlet_Sales            4604.672800
# dtype: float64

# %% [markdown]
# ## **Introduction to Seaborn**

# %%
from ast import increment_lineno
import seaborn as sns
sns.set()
sns.set(style="darkgrid")

import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
plt.rcParams['figure.figsize']=(10,10)

# %%
sns_data = sns_data.dropna(how='any')
sns_data['Visibility_Scaled'] = sns_data["Item_Visibility"]*100
sns_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                       1999
# 1   Soft Drinks   48.2692            OUT018                       2009
# 2          Meat  141.6180            OUT049                       1999
# 4     Household   53.8614            OUT013                       1987
# 5  Baking Goods   51.4008            OUT018                       2009
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# ...
